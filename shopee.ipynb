# %%
from selenium import webdriver
import requests
import json
import urllib
from pprint import pprint
from selenium import webdriver
import time
import re
import csv

# %%
driver = webdriver.Chrome('./chromedriver')
driver.maximize_window()
url_first = 'https://shopee.tw/search?keyword=%E7%94%B7%E5%A5%B3%E9%9E%8B%E6%AC%BE&page=0'
driver.get(url_first)
time.sleep(2)
item = driver.find_element_by_xpath(
    '//*[@id="main"]/div/div[3]/div/div[2]/div[2]/div[2]/div[1]/a')
id = item.get_attribute('href')
shopid = id.rsplit('.',2)[1]
itemid = id.rsplit('.',2)[2]
print(shopid)
print(itemid)
# //*[@id="main"]/div/div[3]/div/div[2]/div[2]/div[2]/div[{i}]/a   total 50



driver.close()
# Out:
# 431599137
# 11105823996

# %%
item_url=f'https://shopee.tw/api/v2/item/get_ratings?filter=0&flag=1&itemid={itemid}&limit=6&offset=0&shopid={shopid}&type=0'
r=requests.get(item_url)
data=r.json()
data=data['data']['ratings'][0]['comment']

# %%
pprint(data)
# Out:
# '穿起來很舒服！'

# %%
pprint(data)
# Out:
# [{'ItemRatingReply': {'cmtid': 4964767493,
#                       'comment': '感謝您實拍分享 下次購物給您折扣碼使用 麻煩您屆時截圖私訊小編',
#                       'ctime': 1622731184,
#                       'editable': None,
#                       'filter': None,
#                       'is_hidden': False,
#                       'itemid': None,
#                       'mentioned': None,
#                       'mtime': 1622731184,
#                       'opt': None,
#                       'orderid': 75732251436845,
#                       'rating': None,
#                       'rating_star': None,
#                       'shopid': None,
#                       'status': None,
#                       'userid': 431618714},
#   'anonymous': True,
#   'author_portrait': 'ef8dbbad0256c7dbb50ab4b2f819ce47',
#   'author_shopid': 8586859,
#   'author_username': 'l*****1',
#   'cmtid': 4964767493,
#   'comment': '穿起來超軟又超蘇服，而且超好穿又可愛 ，跟女的兒一人一雙。賣家也很貼心的解決我的尺寸問題。',
#   'ctime': 1622691908,
# ...

# %%
keyword = '男女鞋款'
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36 Edg/88.0.705.68',
    'x-api-source': 'pc',
    'referer': f'https://shopee.tw/search?keyword={urllib.parse.quote(keyword)}'
}

s = requests.Session()
url = 'https://shopee.tw/api/v4/search/product_labels'
r = s.get(url, headers=headers)

base_url = 'https://shopee.tw/api/v2/search_items/'
query = f"by=relevancy&keyword={keyword}&limit=50&newest=0&order=desc&page_type=search&version=2"
url = base_url + '?' + query
r = s.get(url, headers=headers)
if r.status_code == requests.codes.ok:
    data = r.json()
    
pprint(data)

# %%
data=data['items']['shopid']['']
pprint(data)
# Out:
# [{'add_on_deal_info': None,
#   'ads_keyword': 'wkdaelpmissisiht',
#   'adsid': 16509193,
#   'algo_image': None,
#   'badge_icon_type': 0,
#   'brand': None,
#   'bundle_deal_info': None,
#   'campaign_stock': None,
#   'campaignid': 9463723,
#   'can_use_bundle_deal': False,
#   'can_use_cod': True,
#   'can_use_wholesale': False,
#   'catid': 64,
#   'cb_option': 0,
#   'cmt_count': 21,
#   'coin_earn_label': None,
#   'collection_id': None,
#   'ctime': 1617347838,
#   'currency': 'TWD',
#   'deduction_info': 'YmZmdG9jc2c2LmNuSndTYrY6qcqM0YBB7JUEvzyQ3CkMpCSs/KiPFqH+v4LXTVoO8uD7v5Tyt9dLiSNs8fGwWoDA7vE0TAoZOTm6mVDYd+sOfdqZFmh80UEsOU0BWZveGLzfV4JE525c0DbSkI+9Xg==',
#   'discount': '5.7',
#   'display_name': None,
#   'distance': None,
#   'exclusive_price_info': None,
#   'fe_flags': None,
#   'flag': 65536,
#   'flash_sale': None,
#   'group_buy_info': None,
#   'has_group_buy_stock': None,
#   'has_lowest_price_guarantee': False,
#   'hidden_price_display': None,
# ...
