# %%
from selenium import webdriver
import time
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
#先把全部有的欄位(安全設備)抓下來，其他大項可以依照這方法抓ex外部設備
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'}
equipment_all1 = []
url='https://www.hotcar.com.tw/CWA/CWA060.html?TSEQNO=236856'
r=requests.get(url,headers=headers)
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml')
print(soup)
car_info=soup.find_all(id='components')
car_info2 = BeautifulSoup(str(car_info), 'html.parser')
car_info3 = car_info2.find_all('li')
for i in car_info3:
    equipment_all1.append(i.text.strip())
print(equipment_all1)
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <title>HOT好車大聯盟|優質二手車</title>
# <meta content="!" name="fragment"/>
# <meta content="HOT好車大聯盟|優質二手車" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="'https://www.hotcar.com.tw/CWA/CWA060.html" property="og:url"/>
# <meta content="" property="og:image"/>
# <meta content="HOT好車大聯盟|優質二手車" property="og:title"/>
# <meta content="HOT,HOT大聯盟,HOT中古車,HOT認證中古車,好車大聯盟,HOT好車大聯盟" property="og:keywords"/>
# <meta class="intro" content="" property="og:description"/>
# <meta content="HOT好車大聯盟推薦您二手車，讓我們與您一起挑選最高品質的認證車、保固車，讓您買到符合期待的優質好車！" property="og:description"/>
# <meta contect="HOT好車大聯盟" property="og:author"/>
# <meta content="200" property="og:image:width"/>
# <meta content="200" property="og:image:height"/>
# <meta content="" property="og:image:secure_url"/>
# <meta content="HOT好車大聯盟|優質二手車" name="site_name"/>
# <meta content="product" name="type"/>
# <meta content="'https://www.hotcar.com.tw/CWA/CWA060.html" name="url"/>
# <meta content="" name="image"/>
# <meta content="HOT好車大聯盟|優質二手車" name="title"/>
# <meta content="HOT,HOT大聯盟,HOT中古車,HOT認證中古車,好車大聯盟,HOT好車大聯盟" name="keywords"/>
# <meta content="HOT好車大聯盟推薦您二手車，讓我們與您一起挑選最高品質的認證車、保固車，讓您買到符合期待的優質好車！" name="description"/>
# <meta contect="HOT好車大聯盟" name="author"/>
# <!--20190124唐加圖靈start-->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-TR85468');</script>
# <!-- End Google Tag Manager -->
# <!--20190124唐加圖靈end-->
# </head>
# <body style="display: none;">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TR85468" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <h1 itemprop="name" style="display:none;">HOT大聯盟|優質二手車</h1>
# <form>
# <!-- <div id="soldout">sold out</div> -->
# <!-- <img id="soldout" src="/image/SOLD@2x.png" class="img-sold"> -->
# <div class="programPannel" data-bind="css: id">
# <div data-bind='component: {name:"ui-header_CWA060", params: {viewModel: "CWA"}}' id="header"></div>
# <div class="contentin_060" id="contentin">
# <div class="container" data-bind="with:editSection">
# <div id="sitemap">
# <ul>
# <!--
#                         <li itemscope="" itemtype="">
#                             <a title="回首頁" itemprop="url"><span
#                                     itemprop="title">首頁</span></a>
#                         </li>
#                         <li itemscope="" itemtype="">
#                             <span itemprop="title">車輛搜尋</span>
#                         </li>
#                         <li itemscope="" itemtype="">
#                             <span itemprop="title" data-bind="html:BRANDNM()+' '+CARTYPENM()"></span>
#                         </li>
# 						-->
# </ul>
# </div>
# <div class="carin">
# <div class="clearfix">
# <div id="carimg">
# <div id="solDiv"></div>
# <div class="row clearfix">
# <div class="col span_4 fwImage">
# <div class="royalSlider rsDefault" id="gallery-1">
# <a class="rsImg" href="/" id="rsImg_1"></a>
# <a class="rsImg" href="/" id="rsImg_2"></a>
# <a class="rsImg" href="/" id="rsImg_3"></a>
# <a class="rsImg" href="/" id="rsImg_4"></a>
# <a class="rsImg" href="/" id="rsImg_5"></a>
# <a class="rsImg" href="/" id="rsImg_6"></a>
# <a class="rsImg" href="/" id="rsImg_7"></a>
# <a class="rsImg" href="/" id="rsImg_8"></a>
# <a class="rsImg" href="/" id="rsImg_9"></a>
# <a class="rsImg" href="/" id="rsImg_10"></a>
# <a class="rsImg" href="/" id="rsImg_11"></a>
# <a class="rsImg" href="/" id="rsImg_12"></a>
# <a class="rsImg" href="/" id="rsImg_13"></a>
# <a class="rsImg" href="/" id="rsImg_14"></a>
# <a class="rsImg" href="/" id="rsImg_15"></a>
# <a class="rsImg" href="/" id="rsImg_16"></a>
# <a class="rsImg" href="/" id="rsImg_17"></a>
# <a class="rsImg" href="/" id="rsImg_18"></a>
# <a class="rsImg" href="/" id="rsImg_19"></a>
# <a class="rsImg" href="/" id="rsImg_20"></a>
# </div>
# </div>
# </div>
# <!--<img src="../app/resources/2018/images/car01.jpg" width="100%"/>-->
# <!-- <div id="box" style="display:none;" data-bind = "click:$root.editSection.fingerTouch"></div>
#                             <div class="bxslider"> -->
# <!-- ko foreach: photoList -->
# <!-- <a id='mainPhoto' href="javascript: void(0);" data-bind = "click:$root.editSection.imgDetail">
#                                     <div id='mainPhotoChoose' class="img" data-bind="style:{'background-image':'url('+$data+')'}"></div>
#                                 </a> -->
# <!-- <div class="img" data-bind="style:{'background-image':'url('+$data+')'}"></div> -->
# <!-- /ko -->
# <!-- </div> -->
# <!--<input type="submit" value="車輛收藏" class="car-btn collection">-->
# <div class="car-btn collection collectionDesktop" data-bind="click:collectionCarClick" style="cursor: pointer;">
# <div data-bind="style:{display:collectionCD()=='N'?'':'none'}">
# <span>加入收藏</span>
# <img height="20" src="../app/resources/2018/images/svg/collection.svg"/>
# </div>
# <div data-bind="style:{display:collectionCD()=='Y'?'':'none'}">
# <span>已收藏</span>
# <img height="20" src="../app/resources/2018/images/svg/collection.svg"/>
# <span id="collectionCount" style="color: #fd661d;font-size: 1.25em;display:none;"></span> <!--20191014 ADD BY SS ADAM REASON.隱藏已收藏數字-->
# </div>
# </div>
# <div class="car-btn comparing comparingDesktop" data-bind="click:compareCarClick" style="cursor: pointer;">
# <span data-bind="style:{display:compareCD()=='N'?'':'none'}">加入比較</span>
# <span data-bind="style:{display:compareCD()=='Y'?'':'none'}">已比較</span>
# <img height="20" src="../app/resources/2018/images/svg/comparing.svg"/>
# </div>
# <div class="car-btn collection collectionMobile" data-bind="click:collectionCarClick" style="cursor: pointer;display: none;">
# <span data-bind="style:{display:collectionCD()=='N'?'':'none'}">加入收藏</span>
# <span data-bind="style:{display:collectionCD()=='Y'?'':'none'}">已收藏</span>
# <img height="20" src="../app/resources/2018/images/svg/collection.svg"/>
# </div>
# <div class="car-btn comparing comparingMobile" data-bind="click:compareCarClick" style="cursor: pointer;display: none;">
# <span data-bind="style:{display:compareCD()=='N'?'':'none'}">加入比較</span>
# <span data-bind="style:{display:compareCD()=='Y'?'':'none'}">已比較</span>
# <img height="20" src="../app/resources/2018/images/svg/comparing.svg"/>
# </div>
# <!-- <div class="carpage">
#                                 <a href=""> <span data-bind="html:nowPage">1</span> / <span
#                                         data-bind="html:photoList().length">20</span> </a>
#                             </div> -->
# </div>
# <div id="cartxt">
# <div id="cartxtin">
# <h2 data-bind="html:SUBJECT"></h2>
# <h1 data-bind="html:BRANDCNM()+' '+CARTYPENM()"></h1>
# <div class="location">
# <span data-bind="html:MCITYNM(),click:cityClick" style="cursor: pointer;"></span>
# <span data-bind="html:' / '"></span>
# <span data-bind="html:NAME(),click:nameClick" style="cursor: pointer;"></span>
# </div>
# <div class="icon-certified-in" data-bind="style:{display:CERSTS()==4?'':'none'},click:openCert" style="cursor: pointer;">
# <img src="/image/icon-certified_silver.png" width="50"/>
# </div>
# <div class="icon-warranty-in" data-bind="style:{display:WARCD()=='Y'?'':'none'},click:openWar" style="cursor: pointer;">
# <img src="/image/icon-certified_gold.png" width="50"/>
# </div>
# </div>
# <div id="cartxtinmobile">
# <h2 data-bind="html:SUBJECT"></h2>
# <h3 data-bind="html:BRANDCNM()+' '+CARTYPENM()+' '+CARYY()+' '+CCNUM_R1()"></h3>
# <!-- <div class="location" data-bind="html:MCITYNM()+' / '+NAME()"></div> -->
# <div class="location">
# <span data-bind="html:MCITYNM(),click:cityClick"></span>
# <span data-bind="html:' / '"></span>
# <span data-bind="html:NAME(),click:nameClick"></span>
# </div>
# <!-- <h4 style="color: #FD521D">
#                                     <span data-bind="html:SALAMT1().replace('萬','')" style="font-size: 2.6em"></span>萬
#                                 </h4> -->
# <div class="icon-certified-in" data-bind="style:{display:CERSTS()==4?'':'none'},click:openCert" style="cursor: pointer;">
# <img alt="認證車" src="/image/icon-certified_silver_mobile.svg" width="40"/>
# </div>
# <div class="icon-warranty-in" data-bind="style:{display:WARCD()=='Y'?'':'none'},click:openWar" style="cursor: pointer;">
# <img alt="認證車" src="/image/icon-certified_gold_mobile.svg" width="40"/>
# </div>
# </div>
# <div class="web-btn" data-bind="style:{display:CERSTS()!=4?'none':'inline-block'}">
# <a href="CWA110_2018.html#committed01"><div data-bind="html:CERCDText(),style:{display:CERSTS()!=4?'none':'block'}"></div></a>
# </div>
# <div class="web-btn" data-bind="style:{display:WARCD()!='Y'?'none':'inline-block'}">
# <a href="CWA110_2018.html#committed02"><div data-bind="html:WARCDText(),style:{display:WARCD()!='Y'?'none':'block'}"></div></a>
# </div>
# <div class="title price">    售價
#                                 <span class="special-offer" data-bind="style:{display:$.trim(specialPrice.PRICE())!=''?'none':''}">
# <span class="big" data-bind="html:SALAMT"></span>萬</span>
# <!-- 20200302 ADD BY SS ADAM REASON.增加hot外促活動 -->
# <div class="promotion_cwa060" style="display:none;">
# <a data-bind="attr:{href:'https://www.hotcar.com.tw/ADSET/HOT202002/index.html'}" id="promotion_cwa060_btn" target="_blank">
# <img class="promotion_cwa060_img" src="../App/Resources/images/promotion_cwa060_0227.png"/>
# </a>
# </div>
# </div>
# <div class="promotion_cwa060_mobile" style="display:none;">
# <a data-bind="attr:{href:'https://www.hotcar.com.tw/ADSET/HOT202002/index.html'}" id="promotion_cwa060_btn_mobile" target="_blank">
# <img class="promotion_cwa060_img" src="../App/Resources/images/promotion_cwa060_0227.png"/>
# </a>
# </div>
# <ul id="price-status">
# <li class="special-offer" data-bind="style:{display:$.trim(specialPrice.PRICE())!=''?'none':'none'}">
# <span class="big" data-bind="html:SALAMT"> </span>萬
#                                 </li>
# <li data-bind="style:{display:$.trim(specialPrice.PRICE())!=''?'':'none'}" id="original-price">原價
#                                     <span data-bind="html:SALAMT"></span> 萬
#                                 </li>
# <li data-bind="style:{display:$.trim(specialPrice.PRICE())!=''?'':'none'}" id="offer">
# <span>限時特價倒數</span>
# </li>
# <li class="special-offer" data-bind="style:{display:$.trim(specialPrice.PRICE())!=''?'':'none'}">限時特價
#                                     <span class="big" data-bind="html:specialPrice.PRICE"></span>萬
#                                 </li>
# <li class="special-offer-time" data-bind="style:{display:$.trim(specialPrice.PRICE())!=''?'':'none'}">剩餘
#                                     <span class="big" data-bind="html:specialPrice.COUNTDOWN"></span>
# </li>
# <li id="location-btn"><a data-bind="attr:{href:'CWA070_2018.html?SEQNO='+SEQNO()}" id="location-btn-a" target="_blank">商家資訊</a></li>
# <li id="contact-btn"><a data-bind="click:openCwa060Report" id="contact-btn-a" style="cursor: pointer;">車輛留言</a></li>
# </ul>
# <div data-bind='component: {name:"ui-share", params: {viewModel: socialShare,alertFlg:"Y"}}' id="otherlink"></div>
# </div>
# </div>
# </div>
# <div class="carin">
# <div class="title information">    基本情報</div>
# <div class="clearfix">
# <div class="table">
# <div class="tablein">
# <div class="item">廠牌</div>
# <div class="text" data-bind="html:BRANDNM" style="overflow: hidden;"></div>
# <div class="item">車型</div>
# <div class="text" data-bind="html:CARTYPENM"></div>
# </div>
# <div class="tablein">
# <div class="item">傳動<br/>種類</div>
# <div class="text" data-bind="html:WDTYPENM">二輪</div>
# <div class="item">年份</div>
# <div class="text" data-bind="html:CARYY">2013</div>
# </div>
# </div>
# <div class="table">
# <div class="tablein">
# <div class="item">排氣量</div>
# <div class="text" data-bind="html:CCNUM_R1">1984</div>
# <div class="item">車種</div>
# <div class="text" data-bind="html:BODYTYPENM">轎車</div>
# </div>
# <div class="tablein">
# <div class="item">排檔</div>
# <div class="text" data-bind="html:GEARTYPENM">自排</div>
# <div class="item">車色</div>
# <div class="text" data-bind="html:CCORLORNM">銀色系</div>
# </div>
# </div>
# </div>
# <div class="clearfix">
# <div class="table">
# <div class="tablein">
# <div class="item">目前<br/>里程</div>
# <div class="text" data-bind="html:KM1">134,584</div>
# <div class="item">燃油<br/>種類</div>
# <div class="text" data-bind="html:GASTYPENM">汽油</div>
# </div>
# </div>
# <div class="table web" style="display: none;">
# <div class="tablein">
# <div class="item">車商<br/>地址</div>
# <div class="text" style="flex: 5.85;"><a data-bind="html:ADDRESS,attr:{href:MAPURL()}" style="line-height: 34px;" target="_blank"></a></div>
# </div>
# </div>
# </div>
# <div class="clearfix">
# <div class="table web">
# <div class="tablein">
# <div class="item">車商<br/>電話</div>
# <div class="text" style="flex: 5.5;"><a data-bind="html:MCELLPHONE,attr:{href:'tel:'+MCELLPHONE()}"></a></div>
# </div>
# </div>
# <div class="table">
# <div class="tablein">
# <div class="item">車商<br/>地址</div>
# <div class="text" style="flex: 5.85;"><a data-bind="html:ADDRESS,attr:{href:MAPURL()}" style="line-height: 34px;" target="_blank"></a></div>
# </div>
# </div>
# </div>
# <p class="small">※目前里程數僅揭露，不具保證效力</p>
# </div>
# <div class="carin">
# <div class="title components">    配件項目</div>
# <!-- <div id="components">
#                         <ul>
#                             <li data-bind="css:EQUIP10()=='Y'?'check':''">皮椅</li>
#                             <li data-bind="css:EQUIP12()=='Y'?'check':''">電動座椅 (<span
#                                     data-bind="html:EQUIP12MEMO()==''?'0':EQUIP12MEMO()"></span>)
#                             </li>
#                             <li data-bind="css:EQUIP08()=='Y'?'check':''">電動窗</li>
#                             <li data-bind="css:EQUIP09()=='Y'?'check':''">電動後視鏡</li>
#                             <li data-bind="css:EQUIP07()=='Y'?'check':''">天窗</li>
#                             <li data-bind="css:EQUIP13()=='Y'?'check':''">CD</li>
#                             <li data-bind="css:EQUIP14()=='Y'?'check':''">VCD</li>
#                             <li data-bind="css:EQUIP15()=='Y'?'check':''">DVD</li>
#                             <li data-bind="css:EQUIP03()=='Y'?'check':''">恆溫空調</li>
#                             <li data-bind="css:EQUIP16()=='Y'?'check':''">定速系統</li>
#                             <li data-bind="css:EQUIP06()=='Y'?'check':''">衛星導航</li>
#                             <li data-bind="css:EQUIP01()=='Y'?'check':''">安全氣囊 (<span
#                                     data-bind="html:EQUIP01MEMO()==''?'0':EQUIP01MEMO()"></span>)
#                             </li>
#                             <li data-bind="css:EQUIP04()=='Y'?'check':''">倒車雷達</li>
# 							<li data-bind="css:EQUIP05()=='Y'?'check':''">倒車影像</li>
#                             <li data-bind="css:EQUIP17()=='Y'?'check':''">鋁圈</li>
#                             <li data-bind="css:EQUIP11()=='Y'?'check':''">防盜器</li>
#                             <li data-bind="css:EQUIP18()=='Y'?'check':''">HID</li>
#                             <li data-bind="css:EQUIP19()=='Y'?'check':''">Push Start</li>
#                             <li data-bind="css:EQUIP02()=='Y'?'check':''">ABS</li>
#                             <li data-bind="css:EQUIP20()=='Y'?'check':''">Hybrid</li>
#                         </ul>
#                     </div> -->
# <div id="components">
# <div>
# <div class="title"><span style="padding-bottom: 1px;border-bottom: 2px solid">安全配備</span></div>
# <ul>
# <li data-bind="style:{display:EQUIP01()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP01.png"/>
#                                     安全氣囊
#                                 </li>
# <li data-bind="style:{display:EQUIP02()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP02.png"/>
#                                     ABS
#                                 </li>
# <li data-bind="style:{display:EQUIP16()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP16.png"/>
#                                     定速
#                                 </li>
# <li data-bind="style:{display:EQUIP05()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP05.png"/>
#                                     倒車影像
#                                 </li>
# <li data-bind="style:{display:EQUIP04()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP04.png"/>
#                                     倒車雷達
#                                 </li>
# <li data-bind="style:{display:EQUIP06()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP06.png"/>
#                                     衛星導航
#                                 </li>
# <li data-bind="style:{display:EQUIP21()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP21.png"/>
#                                     胎壓偵測
#                                 </li>
# <li data-bind="style:{display:EQUIP22()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP22.png"/>
#                                     霧燈
#                                 </li>
# <li data-bind="style:{display:EQUIP32()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP32.png"/>
#                                     ESP
#                                 </li>
# <li data-bind="style:{display:EQUIP23()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP23.png"/>
#                                     車道偏移系統
#                                 </li>
# <li data-bind="style:{display:EQUIP24()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP24.png"/>
#                                     車側盲點偵測系統
#                                 </li>
# </ul>
# </div>
# <div>
# <div class="title"><span style="padding-bottom: 1px;border-bottom: 2px solid">外部配備</span></div>
# <ul>
# <li data-bind="style:{display:EQUIP17()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP17.png"/>
#                                     鋁圈
#                                 </li>
# <li data-bind="style:{display:EQUIP09()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP09.png"/>
#                                     電動後視鏡
#                                 </li>
# <li data-bind="style:{display:EQUIP18()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP18.png"/>
#                                     HID頭燈
#                                 </li>
# <li data-bind="style:{display:EQUIP07()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP07.png"/>
#                                     天窗
#                                 </li>
# <li data-bind="style:{display:EQUIP25()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP25.png"/>
#                                     電動尾門
#                                 </li>
# <li data-bind="style:{display:EQUIP26()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP26.png"/>
#                                     電動滑門
#                                 </li>
# <li data-bind="style:{display:EQUIP27()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP27.png"/>
#                                     全景天窗
#                                 </li>
# </ul>
# </div>
# <div>
# <div class="title"><span style="padding-bottom: 1px;border-bottom: 2px solid">內部配備</span></div>
# <ul>
# <li data-bind="style:{display:EQUIP10()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP10.png"/>
#                                     皮椅
#                                 </li>
# <li data-bind="style:{display:EQUIP03()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP03.png"/>
#                                     恆溫空調
#                                 </li>
# <li data-bind="style:{display:EQUIP28()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP28.png"/>
# <!--20200620.寧遠.KEYLESS免鑰系統 -> PUSH START -->
# 									PUSH START
#                                 </li>
# <li data-bind="style:{display:EQUIP29()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP29.png"/>
#                                     ISOFIX
#                                 </li>
# <li data-bind="style:{display:EQUIP13()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP13.png"/>
#                                     CD
#                                 </li>
# <li data-bind="style:{display:EQUIP14()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP14.png"/>
#                                     VCD
#                                 </li>
# <li data-bind="style:{display:EQUIP15()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP15.png"/>
#                                     DVD
#                                 </li>
# <li data-bind="style:{display:EQUIP30()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP30.png"/>
#                                     液晶螢幕
#                                 </li>
# <li data-bind="style:{display:EQUIP12()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP12.png"/>
#                                     電動座椅
#                                 </li>
# <li data-bind="style:{display:EQUIP31()=='Y'?'':'none'}">
# <img src="../image/icon-components/EQUIP31.svg"/>
# <!--20200620.寧遠.方向排換檔控制 -> 方向盤換檔撥片 -->
# 									方向盤換檔撥片
#                                 </li>
# </ul>
# </div>
# <div data-bind='component: {name:"ui-share", params: {viewModel: socialShare,alertFlg:"N"}}' id="otherlinkMobile" style="margin-left: 10px;"></div>
# </div>
# </div>
# <!--20190104唐加-->
# <div class="carin">
# <div class="title information">    車輛描述</div>
# <div class="ckediter" data-bind="html:INTRO"></div>
# </div>
# <div data-bind="style:{display:promottionCar().length==0?'none':''}" id="car">
# <div class="title-more"><span class="in">您可能有興趣</span></div>
# <!-- <?/*四個一排-桌機用*/?> -->
# <div class="car-four clearfix">
# <!-- <?/*兩個一排-手機用*/?> -->
# <div class="car-two clearfix">
# <!-- ko foreach: promottionCar -->
# <div class="car">
# <a class="car-a" data-bind="attr:{href:'CWA060.html?TSEQNO='+TSEQNO}" target="_blank">
# <div class="img" data-bind="style:{'background-image':'url('+PHOTOPATH+')'}"></div>
# </a>
# <h4 class="name"><a class="car-a" data-bind="html:BRANDNM+' '+CARTYPENM" href=""></a>
# <div>
# <div class="icon-certified_060" data-bind="style:{display:CERCD=='Y'?'':'none'}">
# <img alt="認證車" src="/image/icon-certified_silver.png" width="50"/>
# </div>
# <div class="icon-warranty_060" data-bind="style:{display:WARCD=='Y'?'':'none'}">
# <img alt="保固車" src="/image/icon-certified_gold.png" width="50"/>
# </div>
# <div class="icon-certified_060-mobile" data-bind="style:{display:CERCD=='Y'?'':'none'}">
# <img alt="認證車" src="/image/icon-certified_silver_mobile.svg" width="40"/>
# </div>
# <div class="icon-warranty_060-mobile" data-bind="style:{display:WARCD=='Y'?'':'none'}">
# <img alt="保固車" src="/image/icon-certified_gold_mobile.svg" width="40"/>
# </div>
# </div>
# </h4>
# <!--<div class="label row">-->
# <!--<ul>-->
# <!--<li><span data-bind="html:KM1">3.5</span>萬公里</li>-->
# <!--<li data-bind="html:CARYY"></li>-->
# <!--<li data-bind="html:CCNUM_R+' L'"></li>-->
# <!--</ul>-->
# <!--</div>-->
# <!--<div class="price"><span class="font-big"-->
# <!--data-bind="html:SALAMT1.replace('萬','')"></span>-->
# <!--萬-->
# <!--</div>-->
# <!--<div class="rel">-->
# <!--<div class="icon-certified-in"-->
# <!--data-bind="style:{display:CERPHOTO.indexOf('Certification')>-1?'':'none'}">認 證-->
# <!--</div>-->
# <!--<div class="icon-warranty-in"-->
# <!--data-bind="style:{display:WARPHOTO.indexOf('Warranty')>-1?'':'none'}">保 固-->
# <!--</div>-->
# <!--</div>-->
# <div class="date" data-bind="html:CARYM.substr(0,4)+'年 / '+KM1+'萬公里'">
# </div>
# <div class="price">
# <span class="font-big" data-bind="html:SALAMT1.replace('萬','')"></span>萬
#                                 </div>
# <div class="location" data-bind="html:CITYNM+'/'+NAME"></div>
# </div>
# <!-- /ko -->
# </div>
# <div class="car-two clearfix">
# <!-- ko foreach: promottionCar1 -->
# <div class="car">
# <a class="car-a" data-bind="attr:{href:'CWA060.html?TSEQNO='+TSEQNO}" target="_blank">
# <div class="img" data-bind="style:{'background-image':'url('+PHOTOPATH+')'}"></div>
# </a>
# <h4 class="name"><a class="car-a" data-bind="html:BRANDNM+' '+CARTYPENM" href=""></a></h4>
# <!--<div class="label row">-->
# <!--<ul>-->
# <!--<li><span data-bind="html:KM1">3.5</span>萬公里</li>-->
# <!--<li data-bind="html:CARYY"></li>-->
# <!--<li data-bind="html:CCNUM_R+' L'"></li>-->
# <!--</ul>-->
# <!--</div>-->
# <!--<div class="price"><span class="font-big"-->
# <!--data-bind="html:SALAMT1.replace('萬','')"></span>-->
# <!--萬-->
# <!--</div>-->
# <!--<div class="rel">-->
# <!--<div class="icon-certified-in"-->
# <!--data-bind="style:{display:CERPHOTO.indexOf('Certification')>-1?'':'none'}">認 證-->
# <!--</div>-->
# <!--<div class="icon-warranty-in"-->
# <!--data-bind="style:{display:WARPHOTO.indexOf('Warranty')>-1?'':'none'}">保 固-->
# <!--</div>-->
# <!--</div>-->
# <div class="date" data-bind="html:CARYM.substr(0,4)+'年 / '+KM1+'萬公里'">
# </div>
# <div class="price">
# <span class="font-big" data-bind="html:SALAMT1.replace('萬','')"></span>萬
#                                 </div>
# <div class="location" data-bind="html:CITYNM+'/'+NAME"></div>
# <div>
# <div class="icon-certified_060" data-bind="style:{display:CERCD=='Y'?'':'none'}">
# <img alt="認證車" src="/image/icon-certified_silver.png" width="50"/>
# </div>
# <div class="icon-warranty_060" data-bind="style:{display:WARCD=='Y'?'':'none'}">
# <img alt="保固車" src="/image/icon-certified_gold.png" width="50"/>
# </div>
# <div class="icon-certified_060-mobile" data-bind="style:{display:CERCD=='Y'?'':'none'}">
# <img alt="認證車" src="/image/icon-certified_silver_mobile.svg" width="40"/>
# </div>
# <div class="icon-warranty_060-mobile" data-bind="style:{display:WARCD=='Y'?'':'none'}">
# <img alt="保固車" src="/image/icon-certified_gold_mobile.svg" width="40"/>
# </div>
# </div>
# </div>
# <!-- /ko -->
# </div>
# </div>
# </div>
# <div data-bind='component: {name:"ui-cwa060-report", params: {viewModel: cwa060Report}}'></div>
# <!--#include file="view/ad.html"-->
# <!--20181218唐加-->
# <div class="row" style="padding: 0px;">
# <div data-bind='component: {name:"ui-banner", params: {viewModel: banner}}'></div>
# </div>
# <!--20181218唐加-->
# </div>
# </div>
# <div class="wow fadeInUp mobile" data-wow-delay="900ms" data-wow-duration="1000ms" id="phone-btn">
# <!-- <div>HOT好車，3大認證，五大保固，不符原價買回</div> -->
# <!-- <a href="CWA110_2018.html#committed02"><div data-bind="html:editSection.phoneBtnText(),style:{display:editSection.CERCD()!='Y'&&editSection.WARCD()!='Y'?'none':''}">
#
#             </div></a> -->
# <a class="car-a" data-bind="attr:{href:'tel:'+editSection.MCELLPHONE()}"><img src="../app/resources/2018/images/svg/phone.svg" width="35"/> 立即聯絡 <span data-bind="html:editSection.MCELLPHONE"></span></a>
# </div>
# <div data-bind='component: {name:"ui-alert", params: {viewModel: commonSection.kAlert}}'></div>
# <div data-bind='component: {name:"ui-footer2018", params: {viewModel: "CWA", btnShow:true}}'></div>
# </div>
# </form>
# </body>
# </html>
# <!-- <link href="../app/resources/css/lightbox.css" rel="Stylesheet"/> -->
#
# ['安全氣囊', 'ABS', '定速', '倒車影像', '倒車雷達', '衛星導航', '胎壓偵測', '霧燈', 'ESP', '車道偏移系統', '車側盲點偵測系統', '鋁圈', '電動後視鏡', 'HID頭燈', '天窗', '電動尾門', '電動滑門', '全景天窗', '皮椅', '恆溫空調', 'PUSH START', 'ISOFIX', 'CD', 'VCD', 'DVD', '液晶螢幕', '電動座椅', '方向盤換檔撥片']

# %%
#找到安全設備中目前有的配備
from selenium import webdriver
import time
driver = webdriver.Chrome('../chromedriver')
url='https://www.hotcar.com.tw/CWA/CWA060.html?TSEQNO=236856'
driver.get(url)#.encoding='utf-8'
time.sleep(5)
title = driver.find_element_by_xpath(
        '//*[@id="components"]/div[1]')
print(title.text.split('\n'))
# Out:
# ['安全配備', '安全氣囊', 'ABS', '倒車影像', '倒車雷達', 'ESP', '車側盲點偵測系統']

# %%
#建一個安全設備的dataframe
[list([0]*len(equipment_all1))]
equipments = pd.DataFrame(columns=equipment_all1)
equipments
# Out:
# Empty DataFrame
# Columns: [安全氣囊, ABS, 定速, 倒車影像, 倒車雷達, 衛星導航, 胎壓偵測, 霧燈, ESP, 車道偏移系統, 車側盲點偵測系統, 鋁圈, 電動後視鏡, HID頭燈, 天窗, 電動尾門, 電動滑門, 全景天窗, 皮椅, 恆溫空調, PUSH START, ISOFIX, CD, VCD, DVD, 液晶螢幕, 電動座椅, 方向盤換檔撥片]
# Index: []
#
# [0 rows x 28 columns]

# %%
#有該項設備就變成1
for i in title.text.split('\n'):
    if i in equipment_all1:
        equipments[i] = 1
equipments
# Out:
# Empty DataFrame
# Columns: [安全氣囊, ABS, 定速, 倒車影像, 倒車雷達, 衛星導航, 胎壓偵測, 霧燈, ESP, 車道偏移系統, 車側盲點偵測系統, 鋁圈, 電動後視鏡, HID頭燈, 天窗, 電動尾門, 電動滑門, 全景天窗, 皮椅, 恆溫空調, PUSH START, ISOFIX, CD, VCD, DVD, 液晶螢幕, 電動座椅, 方向盤換檔撥片]
# Index: []
#
# [0 rows x 28 columns]
